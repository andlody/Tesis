# %%
# !python3 --version
# Out:
# Python 3.10.11

# %%
import pandas as pd

dfp = pd.read_csv("../data/raw/productos.csv",delimiter=",")
dfp.head()
# Out:
#    PRD_LVL_CHILD  PRD_LVL_NUMBER  \
# 0          12635           10236
# 1          12636           10237
# 2          12694           10298
# 3          12476           10077
# 4          12575           10177
#
#                                        PRD_FULL_NAME  PRD_LVL_ID COD_DIV  \
# 0  OVALIN CIRCULAR P/SOBREP ORANGE VIDRIOTRANSPAR...           1     T03
# 1    OVALIN CIRCULAR P/SOBREP ORANGE VIDRIO PAVONADO           1     T03
# 2                  LLAVE DUCHA ORANGE FROST S/SALIDA           1     T03
# 3                   SILLA ESTAMBUL FIJA H-602F NEGRA           1     T04
# 4                     MESA DE ESTUDIO ESPAÑA CASTAÑO           1     T04
#
#         DES_DIV COD_AREA DES_AREA COD_DPTO          DES_DPTO  ... COD_SURTIDO  \
# 0      ACABADOS      A11    BAÑOS     D083        SANITARIOS  ...           H
# 1      ACABADOS      A11    BAÑOS     D083        SANITARIOS  ...           H
# 2      ACABADOS      A11    BAÑOS     D082  GRIFERIA DE BAÑO  ...           H
# 3  HOGAR Y DECO      A13  MUEBLES     D031          OFICINAS  ...           H
# 4  HOGAR Y DECO      A13  MUEBLES     D031          OFICINAS  ...           H
#
#        DESTIPSURTIDO  FLAG_ECOM_VTA_PRV FLAG_ECOM_RETIRO_TDA  \
# 0  Productos en Home                 SI                   SI
# 1  Productos en Home                 SI                   SI
# 2  Productos en Home                 SI                   SI
# 3  Productos en Home                 SI                   SI
# 4  Productos en Home                 SI                   SI
#
#   FLAG_DESPACHO_RANGO IMG_URL  ATR_MOD_DESP    DES_ATR_MOD_DESP  \
# 0                  NO     NaN             2   NO EXPRESS RETAIL
# 1                  NO     NaN             2   NO EXPRESS RETAIL
# 2                  NO     NaN             1  SI  EXPRESS RETAIL
# 3                  NO     NaN             2   NO EXPRESS RETAIL
# 4                  NO     NaN             2   NO EXPRESS RETAIL
#
#          DOWNLOAD_DATE ATR_LONG_TAIL
# 0  2025-07-15 04:00:16           NaN
# 1  2025-07-15 04:00:16           NaN
# 2  2025-07-15 04:00:16           NaN
# 3  2025-07-15 04:00:16           NaN
# 4  2025-07-15 04:00:16           NaN
#
# [5 rows x 85 columns]

# %%
dfp = dfp.drop([
'PRD_LVL_CHILD',
'PRD_LVL_ID',
'COD_STL',
'DES_STL',
'COD_PRV',
'DES_PRV',
'FEC_CRE',
'FEC_MOD',
'PRD_STYLE_IND',
'PAD_LVL_CHILD',
'DIV_LVL_CHILD',
'AREA_LVL_CHILD',
'DPTO_LVL_CHILD',
'LIN_LVL_CHILD',
'AFECTO',
'COD_TIPNEG',
'DES_TIPNEG',
'FLAG_SERV',
'DES_SERV',
'DES_BIGTCK',
'FLAG_BIGTCK',
'COD_BIGTCK',
'COD_SERV',
'COD_CUR',
'DES_CUR',
'COD_TAL',
'DES_TAL',
'VPC_PRD_TECH_KEY',
'VPC_CASE_PACK_ID',
'INNER_PK_TECH_KEY',
'INNER_PACK_ID',
'VPC_TECH_KEY',
'COD_TIPMAR',
'COD_PTOPRECIO',
'DES_PTOPRECIO',
'COD_UMV',
'DES_UMV',
'COD_UMI',
'DES_UMI',
'COD_PRODFIS',
'DES_PRODFIS',
'COD_PERCEP',
'DES_PERCEP',
'DETRACCION',
'COD_BIGTCK_VTEX',
'DES_BIGTCK_VTEX',
'FLAG_ECOM_VTA_PRV',
'FLAG_ECOM_RETIRO_TDA',
'FLAG_DESPACHO_RANGO',
'IMG_URL',
'ATR_MOD_DESP',
'DES_ATR_MOD_DESP',
'DOWNLOAD_DATE',
'ATR_LONG_TAIL',
'COD_DIV',
'COD_AREA',
'COD_DPTO',
'COD_LIN',
'COD_MARCA',
'DESTIPSURTIDO',
'COD_SURTIDO',
'PERECIBLE',
'DESPACHO',
'PRECIAZO',
'COD_UMC',
'DIST_QTY',
'COD_EST',
'DES_EST',
'COD_PROCE',
'COD_PAIS',
'COD_TIPMAN',
'COD_NRO_PIEZAS',
'DES_NRO_PIEZAS',
'LIQUIDACION',
'COD_BAR',
'DES_UMC',
'DES_TIPMAN',
], axis=1)
dfp.columns
# Out:
# Index(['PRD_LVL_NUMBER', 'PRD_FULL_NAME', 'DES_DIV', 'DES_AREA', 'DES_DPTO',
#        'DES_LIN', 'DES_MARCA', 'DES_PROCE'],
#       dtype='object')

# %%
dfp = dfp.rename(columns={'PRD_LVL_NUMBER': 'SKU', 'PRD_FULL_NAME': 'DESCRIPCION'})
dfp
# Out:
#           SKU                                        DESCRIPCION  \
# 0       10236  OVALIN CIRCULAR P/SOBREP ORANGE VIDRIOTRANSPAR...
# 1       10237    OVALIN CIRCULAR P/SOBREP ORANGE VIDRIO PAVONADO
# 2       10298                  LLAVE DUCHA ORANGE FROST S/SALIDA
# 3       10077                   SILLA ESTAMBUL FIJA H-602F NEGRA
# 4       10177                     MESA DE ESTUDIO ESPAÑA CASTAÑO
# ...       ...                                                ...
# 46707  165495                       MOTOSIERRA (X) 45 CC ESP. 16
# 46708  165491     MOTOSIERRA TOYAMA TCS60FP FARMER PRO - 56CC 20
# 46709  165496                     MINI RODILLO CUBREMAS TEKNO 3"
# 46710  165493                MOTOSIERRA TCS58F-G2-20SN-TY FARMER
# 46711  165497        PODADORA DE ALTURA (XP) 32.6 CC 3/8 X 0.050
#
#              DES_DIV  DES_AREA                DES_DPTO              DES_LIN  \
# 0           ACABADOS     BAÑOS              SANITARIOS             OVALINES
# 1           ACABADOS     BAÑOS              SANITARIOS             OVALINES
# 2           ACABADOS     BAÑOS        GRIFERIA DE BAÑO          LLAVE DUCHA
# 3       HOGAR Y DECO   MUEBLES                OFICINAS         SILLAS FIJAS
# 4       HOGAR Y DECO   MUEBLES                OFICINAS      ESCRITORIOS RTA
# ...              ...       ...                     ...                  ...
# 46707  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46708  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46709       ACABADOS  PINTURAS  ACCESORIOS PARA PINTAR  RODILLOS Y BANDEJAS
# 46710  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46711  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN            PODADORAS
#
#        DES_MARCA  DES_PROCE
# 0         ORANGE  IMPORTADO
# 1         ORANGE  IMPORTADO
# 2         ORANGE  IMPORTADO
# 3         ORANGE  IMPORTADO
# 4      POLITORNO  IMPORTADO
# ...          ...        ...
# 46707         SM   NACIONAL
# 46708         SM   NACIONAL
# 46709      TEKNO  IMPORTADO
# 46710         SM   NACIONAL
# 46711         SM   NACIONAL
#
# [46712 rows x 8 columns]

# %%
dfi = pd.read_csv("../data/raw/imagenes.csv", delimiter=",", encoding="utf-8")
dfi = dfi.rename(columns={'sku': 'SKU', 'imgUrl': 'URL'})
dfi.head()
# Out:
#      SKU                                                URL
# 0  10334  https://promart.vteximg.com.br/arquivos/ids/18...
# 1  10237  https://promart.vteximg.com.br/arquivos/ids/50...
# 2  10151  https://promart.vteximg.com.br/arquivos/ids/18...
# 3  10324  https://promart.vteximg.com.br/arquivos/ids/21...
# 4  10236  https://promart.vteximg.com.br/arquivos/ids/38...

# %%
dff = pd.read_csv("../data/raw/ficha.csv", delimiter=",", encoding="utf-8")
dff = dff.rename(columns={'sku': 'SKU', 'data_key': 'KEY', 'data_value': 'VALUE'})
dff.head()
# Out:
#       SKU                       KEY          VALUE
# 0  113229       Altura Del Producto          33 cm
# 1  113229        Ancho Del Producto        57.7 cm
# 2  113229  Profundidad Del Producto        56.5 cm
# 3  113229      Volumen del producto      107581.65
# 4  113229                       Ean  7290106931695

# %%
dfd = pd.read_csv("../data/raw/descripcion.csv", delimiter=",", encoding="utf-8")
dfd = dfd.rename(columns={'sku': 'SKU', 'data_key': 'KEY', 'data_value': 'VALUE'})
dfd.head()
# Out:
#       SKU                    KEY  \
# 0  113229        Características
# 1  113229          Observaciones
# 2  113229  Descripción Emocional
# 3  113231        Características
# 4  113231          Observaciones
#
#                                                VALUE
# 0  Esta duradera casa para mascotas es muy resist...
# 1  Combina un patrón de punto clásico con diseño ...
# 2  Esta duradera casa para mascotas es muy resist...
# 3  Fabricada en resina duradera, esta casa para p...
# 4  Con un diseño para todo tipo de clima, esta ca...

# %%
# Productos - imagenes
df = pd.merge(dfp, dfi, on='SKU', how='left')
df
# Out:
#           SKU                                        DESCRIPCION  \
# 0       10236  OVALIN CIRCULAR P/SOBREP ORANGE VIDRIOTRANSPAR...
# 1       10237    OVALIN CIRCULAR P/SOBREP ORANGE VIDRIO PAVONADO
# 2       10298                  LLAVE DUCHA ORANGE FROST S/SALIDA
# 3       10077                   SILLA ESTAMBUL FIJA H-602F NEGRA
# 4       10177                     MESA DE ESTUDIO ESPAÑA CASTAÑO
# ...       ...                                                ...
# 46708  165495                       MOTOSIERRA (X) 45 CC ESP. 16
# 46709  165491     MOTOSIERRA TOYAMA TCS60FP FARMER PRO - 56CC 20
# 46710  165496                     MINI RODILLO CUBREMAS TEKNO 3"
# 46711  165493                MOTOSIERRA TCS58F-G2-20SN-TY FARMER
# 46712  165497        PODADORA DE ALTURA (XP) 32.6 CC 3/8 X 0.050
#
#              DES_DIV  DES_AREA                DES_DPTO              DES_LIN  \
# 0           ACABADOS     BAÑOS              SANITARIOS             OVALINES
# 1           ACABADOS     BAÑOS              SANITARIOS             OVALINES
# 2           ACABADOS     BAÑOS        GRIFERIA DE BAÑO          LLAVE DUCHA
# 3       HOGAR Y DECO   MUEBLES                OFICINAS         SILLAS FIJAS
# 4       HOGAR Y DECO   MUEBLES                OFICINAS      ESCRITORIOS RTA
# ...              ...       ...                     ...                  ...
# 46708  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46709  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46710       ACABADOS  PINTURAS  ACCESORIOS PARA PINTAR  RODILLOS Y BANDEJAS
# 46711  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46712  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN            PODADORAS
#
#        DES_MARCA  DES_PROCE                                                URL
# 0         ORANGE  IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/38...
# 1         ORANGE  IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/50...
# 2         ORANGE  IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/51...
# 3         ORANGE  IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/38...
# 4      POLITORNO  IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/59...
# ...          ...        ...                                                ...
# 46708         SM   NACIONAL                                                NaN
# 46709         SM   NACIONAL                                                NaN
# 46710      TEKNO  IMPORTADO                                                NaN
# 46711         SM   NACIONAL                                                NaN
# 46712         SM   NACIONAL                                                NaN
#
# [46713 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configurar el estilo de los gráficos
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# Contar productos por división
division_counts = df['DES_DIV'].value_counts().sort_values(ascending=False)

# Crear la gráfica de barras
plt.figure()
sns.barplot(x=division_counts.values, y=division_counts.index, palette="viridis")
plt.title("Cantidad de productos por División", fontsize=16)
plt.xlabel("Cantidad de productos")
plt.ylabel("División")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/b9/czfvlssj4z163jnpkkzwnvgr0000gn/T/ipykernel_72228/3809062533.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=division_counts.values, y=division_counts.index, palette="viridis")

# %%
# Configurar el estilo de los gráficos
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# Contar productos por división
division_counts = df['DES_AREA'].value_counts().sort_values(ascending=False)

# Crear la gráfica de barras
plt.figure()
sns.barplot(x=division_counts.values, y=division_counts.index, palette="viridis")
plt.title("Cantidad de productos por Area", fontsize=16)
plt.xlabel("Cantidad de productos")
plt.ylabel("Area")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/b9/czfvlssj4z163jnpkkzwnvgr0000gn/T/ipykernel_72228/2732634478.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=division_counts.values, y=division_counts.index, palette="viridis")

# %%
# Configurar estilo de los gráficos
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

area_counts = df["DES_AREA"].value_counts().head(18)

fig, axes = plt.subplots(1, 1, figsize=(12, 12))

# Gráfico de pastel por área
axes.pie(area_counts.values, labels=area_counts.index, autopct="%1.1f%%", startangle=140)
axes.set_title("Distribución de productos por Área")

# Ajustar diseño
plt.tight_layout()
plt.show()

# %%
df['DES_MARCA'] = df['DES_MARCA'].fillna('')
df['DES_PROCE'] = df['DES_PROCE'].fillna('')
df['URL'] = df['URL'].fillna('')

# %%
def limipiarTexto(text):
    import re
    text = re.sub(r'[\r\n\t]+', ' ', text).strip()
    return text

def formatearDescripcion(text,marca):
    replacements = [
        (' ' + marca, ''),   # quitamos la marca en la descripcion
        (' /', ''),
        (' p/', ' para '),
        (' c/', ' con '),
        (' ace/', ' acero '),
        (' s/', ' sin '),
        (' d/', ' d '),
        (' v/', ' vaso de '),
        ('sobrep ', 'sobreponer '),
        ('+', ' '),
        (' l/', ' luz ')
    ]
    
    for old, new in replacements:
        text = text.replace(old, new)

    return text


def formatoChunk(p):
    text = formatearDescripcion(p['DESCRIPCION'].lower(),p['DES_MARCA'].lower())
    if p['DES_MARCA'] != '':
        text = text + ' de la marca '+p['DES_MARCA'].lower()

    text = text + f" del area de {p['DES_AREA'].lower()} para los {p['DES_DPTO'].lower()} de la linea {p['DES_LIN'].lower()}"

    if p['DES_PROCE'] != '':
        text = text + ' de procedencia '+p['DES_PROCE'].lower()
    
    #text = text + f" al precio de {str(p['PRECIO'])} soles"

    return limipiarTexto(text)

df['CHUNK_PRODUCTO'] = df.apply(formatoChunk, axis=1)

# %%
age_array = df.sample(n=5)['CHUNK_PRODUCTO'].to_numpy()
age_array
# Out:
# array(['válvula check 1 1/4" horizontal asiento metal cim de la marca cimberio del area de gasfiteria para los accesorios de gasfiteria de la linea valvulas hidraulicas de procedencia nacional',
#        'aplicador d cera para el auto x2 de la marca goodyear del area de herramientas para los automotriz de la linea limpieza y aditivos de procedencia importado',
#        'ovalin rectangular para sobreponer treviso blanco de la marca orange del area de baños para los sanitarios de la linea ovalines de procedencia importado',
#        'reflector led eco 50w ip65 luz fria de la marca lightech del area de iluminacion para los iluminacion exterior de la linea reflectores de procedencia nacional',
#        'manguera 1" duplex verde x 25m de la marca 2m del area de jardin para los mangueras y accesorios para riego de la linea mangueras de procedencia nacional'],
#       dtype=object)

# %%
dff
# Out:
#             SKU                       KEY                 VALUE
# 0        113229       Altura Del Producto                 33 cm
# 1        113229        Ancho Del Producto               57.7 cm
# 2        113229  Profundidad Del Producto               56.5 cm
# 3        113229      Volumen del producto             107581.65
# 4        113229                       Ean         7290106931695
# ...         ...                       ...                   ...
# 1016670  154248                     Color                 Negro
# 1016671  154248                  Material  Plástico/Cobre/Acero
# 1016672  154248                  Garantía               3 meses
# 1016673  154248               Procedencia              Nacional
# 1016674  154248            País de origen                 China
#
# [1016675 rows x 3 columns]

# %%
dfa = pd.DataFrame(columns=["SKU", "CHUNK_FICHA"])

for sku, grupo in dff.groupby("SKU"):
    atributos = ", ".join([f"{row['KEY'].strip().lower()} {str(row['VALUE']).strip().lower()}" for _, row in grupo.iterrows()])
    texto = f"sku {sku}, {atributos}"
    dfa.loc[len(dfa)] = [sku, atributos]

dfa
# Out:
#            SKU                                        CHUNK_FICHA
# 0        10001  volumen del producto 0, ean 6928073681268, tip...
# 1        10002  volumen del producto 0, ean 6928073680025, tip...
# 2        10004  volumen del producto 0, ean 6928073680650, col...
# 3        10005  volumen del producto 0, ean 6928073680049, col...
# 4        10006  volumen del producto 0, ean 6925582161113, col...
# ...        ...                                                ...
# 101134  165467  altura del producto 16.5 cm, ancho del product...
# 101135  165468  altura del producto 8 cm, ancho del producto 2...
# 101136  165469  altura del producto 0.035 cm, ancho del produc...
# 101137  165470  altura del producto 0.045 cm, ancho del produc...
# 101138  165471  altura del producto 24.5 cm, ancho del product...
#
# [101139 rows x 2 columns]

# %%
age_array = dfa.sample(n=5)['CHUNK_FICHA'].to_numpy()
age_array
# Out:
# array(['volumen del producto 0, ean 2000000102597, color no aplica, garantía 1 año, procedencia importado',
#        'volumen del producto 0, ean 2000000156354, color no aplica, garantía 1 año, procedencia nacional',
#        'volumen del producto 0, ean 2000000799902, color no aplica, garantía 1 año, procedencia nacional',
#        'altura del producto 18 cm, ancho del producto 500 cm, volumen del producto 0, ean 7754911000750, tipo de producto cenefa, modelo cars, color multicolor, material otros, garantía 1 año, procedencia nacional',
#        'acabado brillante, tamaño del producto grande, altura del producto 60.00 cm, ancho del producto 120.00 cm, profundidad del producto 0.90 cm, volumen del producto 6480, ean 2000001616420, medidas 120.00x0.90x60.00, tipo de producto piso, modelo sofia, color negro, material arcilla, garantía por defecto de fabricación, procedencia importado, país de origen china'],
#       dtype=object)

# %%
dfd
# Out:
#            SKU                     KEY  \
# 0       113229         Características
# 1       113229           Observaciones
# 2       113229   Descripción Emocional
# 3       113231         Características
# 4       113231           Observaciones
# ...        ...                     ...
# 273985  154248         Características
# 273986  154248           Observaciones
# 273987  154248  Recomendaciones De Uso
# 273988  154248      Advertencia de uso
# 273989  154248   Descripción Emocional
#
#                                                     VALUE
# 0       Esta duradera casa para mascotas es muy resist...
# 1       Combina un patrón de punto clásico con diseño ...
# 2       Esta duradera casa para mascotas es muy resist...
# 3       Fabricada en resina duradera, esta casa para p...
# 4       Con un diseño para todo tipo de clima, esta ca...
# ...                                                   ...
# 273985  Cuerda con mango antideslizante ergonómico. La...
# 273986                                          No aplica
# 273987  Ideal para realizar entrenamiento mediante sal...
# 273988  No permita a los niños usar este producto sin ...
# 273989  Cuerda con mango antideslizante ergonómico. La...
#
# [273990 rows x 3 columns]

# %%
import re
def eliminarHtml(text):
    text = re.sub(r'<[^>]*?>', '', text['VALUE'])
    replacements = [
        (' /', ''),
        ('\n', ''),
        ('/p', ''),
        ('/li', ''),
        ('\xa0', ''),
        ('.h2', '. '),
        ('p•', ''),
        ('/h2', '')
    ]
    
    for old, new in replacements:
        text = text.replace(old, new)
    return text

dfd['VALUE'] = dfd['VALUE'].fillna('')
dfd['VALUE'] = dfd.apply(eliminarHtml, axis=1)

# %%
age_array = dfd.loc[dfd['KEY']=='Descripción Emocional'].sample(n=50)['VALUE'].to_numpy()
#age_array = dfd.loc[dfd['KEY']=='Características'].sample(n=50)['VALUE'].to_numpy()
#age_array = dfd.loc[dfd['KEY']=='Observaciones'].sample(n=50)['VALUE'].to_numpy()
age_array
# Out:
# array(['Suavizante Downy Amanecer 4.8L. Disfruta de lo más nuevo que Promart.pe trae para ti.',
#        'Taladro percutor con un potente motor de 600W de la reconocda marca de herramientas Skil que cuenta con gatillo de control para dos velocidades, puño auxiliar, botón traba y empuñadura Soft Grip para mayor comodidad.',
#        'pLa Tarima Premium 1.5 Plazas Champagne de Madera es la combinación perfecta de elegancia y funcionalidad para tu dormitorio. Con un diseño versátil y patas de metal cromado, esta tarima garantiza durabilidad y resistencia. Su tela resistente y de fácil limpieza la hace ideal para un uso doméstico. Disfruta de un descanso placentero sobre esta tarima de alta calidad que cuenta con una garantía de 5 años. Características de la Tarima Premium 1.5 Plazas Champagne de Madera:ul liDiseño versátil con patas de metal cromado. liTela resistente y de fácil limpieza. liGarantía de 5 años. liIdeal para uso doméstico en dormitorios. liDimensiones: 105 cm de ancho, 190 cm de profundidad y 35 cm de altura./ul',
#        'Realiza distintos trabajos mecánicos con este práctico set de herramientas que Promart.pe trae para ti.',
#        'Calienta tus platillos favoritos con este horno microondas que promart trae para ti. Disfruta de lo más nuevo que Promart.pe trae para ti.',
#        'Flor navideña, invade tu casa con la alegría de la navidad. Con los artículos navideños de Promart.pe.',
#        'Un producto elaborado a base de vidrio, hecho cuidadosamente a la medida de 7 x 7 cm e incorporado con un acabado brillante. Sin duda, un accesorio que añadirá un gran valor estético a tus ambientes.',
#        'Puerta Sinfonia HDF 80 + Marco + 3 Bisagras + Kit de Instalación. Disfruta de lo más nuevo que Promart.pe trae para ti.',
#        'Amplio ropero Florencia para organizar tu ropa dentro de la habitación. Cuenta con6 puertas y 4 cajones, la solución perfecta que combina elegancia con durabilidad. El MDP es un aglomerado de astillas de madera de 0.7 mm de espesor con un tratamiento en fenol que ayuda a prevenir el apolillamiento, muy utilizado en la industria de mueblería gracias a su resistencia y maniobrabilidad.',
#        'Complementa la decoración de tu baño con los mejores accesorios. La jabonera para baño tiene un diseño elegante que destacará dentro de tu baño.',
#        'Cultivar bien la tierra donde plantarás es una labor para tu jardín, vivero o campo de cultivo. La tierra preparada y fertilizada de Garden & Clean reúne en una sola mezcla todos elementos naturales necesarios para una base de tierra fuerte para tus plantas. La tierra preparada y fertilizada incluye en su mezcla completa de componentes como: tierra de chacra, arena de río, alagas marinas, materia orgánica, fertilizante npk, magnesio, sulfato de calcio y ferroso .Promart te trae este poderoso ingrediente a tu cultivo en una presentación en bolsa de 10 kg.',
#        'Ideal para superficies metálicas, sustrato de fiero, madera o concreto previamente imprimado. Cuenta con una gran resistencia a la intemperie.',
#        'Macetero 8.5cm Lótus Granito Estelar. Disfruta de lo más nuevo que Promart.pe trae para ti.',
#        'Soporta camaras HD y FullHD 720p, 1080p. Salida HDMI y VGA.',
#        'Con este nuevo juego de ollas prepara una gran variedad de platos al mejor estilo y los mejores utensilios.',
#        'Manguera Espiral 15m con Pistola 8 Funciones Orange. Disfruta de lo más nuevo que Promart.pe trae para ti.',
#        'Set de 3 espejos en forma de mandala que le darán a tus ambientes ese toque místico y lleno de magia que andas buscando.¡Descubre la Tendencia India!',
#        'Disfrutemos el otoño en nuestra casa con la tendencia Aire Nórdico que Promart trae para ti.Los colores nórdicos son muy suaves y dan mucha calma y tranquilidad a los ambientes.Decora la mesa de tu hogar con los mejores individuales inspirados en diseños escandinavos.',
#        'Prepara los más ricos platos con esta sartén. Su diseño contribuye a que la cocción sea uniforme y rápida, ahorrando así tiempo y energía.',
#        'Un espacio bien iluminado en navidad destaca de los demás. Por esta razón, te traemos estas bonitas luces en forma de cascada que puedes colocarlas en el árbol de navidad, muebles, entrada de tu hogar, ventanas, entre otros.',
#        'Para Promart nuestra preocupación es que siempre quedes conforme con nuestros consejos para  el uso de materiales de calidad, seguridad y adecuada instalación. Le ofrecemos el Desagüe para lavatorio de acero inoxidable de 1 1/4 x 11 tipo Sumidero con rebose. El rebose, viene a  complementar el sifón , permite la adecuada evacuación o retención de agua en el lavamanos. La porcelana permite que el agua no se rebose y se drene rápidamente. Resistente a la corrosión y decoloración por agua. Resistente al efecto de jabones y limpiadores de tocador. Recubrimientos no tóxicos.',
#        'Ideal para colocarla en la puerta principal o habitación, decorativa corona de pinos roja.',
#        'Atornillador de diseño ergonómico, cómodo y de fácil de manejo. Potente incluso en zonas de difícil acceso gracias al alto par de apriete.',
#        'Bienvenido al maravilloso mundo de la domótica, smart home o iluminación inteligente. Llámalo como quieras pero no dejes de probar WIZ, con él puedes controlar toda la iluminación de tu casa usando sólo el app desde tu celular; iluminación conectada para tu día a día.',
#        'pEl Tocador Tuhome Kaia en color caramelo es el mueble perfecto para tu habitación. Con una estructura resistente de melamina, este tocador de fácil armado ofrece 4 amplios cajones para organizar tus pertenencias. Disfruta de su diseño fijo y su altura de 126.50 cm, ideal para uso doméstico. Con este tocador, tendrás a tu alcance un mueble de gran utilidad, con garantía de 6 meses y recomendaciones de limpieza sencillas. Aprovecha la excelente calidad y durabilidad que ofrece Tuhome con el modelo Kaia. Características del Tocador Tuhome Kaia Melamina Caramelo:ul liEstructura resistente de melamina. li4 amplios cajones para organizar tus pertenencias. liAltura de 126.50 cm, ideal para uso doméstico. liFácil armado y recomendaciones de limpieza sencillas./ul',
#        'Práctico kit para realizar distintos trabajos de fijación. Ideal para rieles de pilar ranurado para repisas, sobre paredes solidas y huecas.',
#        'Se utilizan para hacer huecos en madera de diferentes diámetros, así como también, para hacer huecos en plástico y fibra de vidrio.',
#        'pEl strongTaladro Percutor 1/2" 20V BRUSHLESS + 1 Bateria 5.0Ah DCD796P1 Dewalt/strong se caracteriza por tener una broca que no rota sólo sobre sí misma, sino que también realiza movimientos repetitivos de adelante hacia atrás. Esto trae como consecuencia que tenga la alta capacidad de perforar superficies más duras y resistentes. h2Características principales del Taladro Percutor 1/2" 20V BRUSHLESS + 1 Bateria 5.0Ah DCD796P1 Dewalt ul li Herramienta con tecnología sin carbones. li Dispone de dos velocidades. li Potencia acústica: 100 db. li Par de giro máximo 70 Nm. li Ideal para perforar mampostería, ladrillos y bloques.ul h2¿Cuales son las ventajas del Taladro Percutor 1/2" 20V BRUSHLESS + 1 Bateria 5.0Ah DCD796P1 Dewalt? ul li Gran potencia y alto rendimiento li Última tecnología en ejecución y rendimiento li Empuñadura cómoda y fácil de maniobrar li Diseño ergonómico, compacto y ligero li Alta precisión en ejecuciónul h2¿En que superficies usar el Taladro Percutor 1/2" 20V BRUSHLESS + 1 Bateria 5.0Ah DCD796P1 Dewalt? pEl strongTaladro Percutor 1/2" 20V BRUSHLESS + 1 Bateria 5.0Ah DCD796P1 Dewalt/strong ofrece una gran potencia lo cual permite trabajar en superficies muy duras como en baldosas, ladrillos, acero y más. Encuentra aquí mas a href="https://www.promart.pe/taladros-dewalt"taladros Dewalt./ap',
#        'pEl Toallero Doble Funky Sensea es la combinación perfecta de calidad, resistencia y elegancia para tu baño. Con un diseño brillante y acabado liso en color blanco, este toallero de 55 cm de ancho ofrece máxima organización y durabilidad. Fabricado en plástico Abs, garantiza una fácil limpieza y mantenimiento. Instálalo fácilmente en la pared con el kit de instalación incluido y disfruta de un toque moderno y funcional en tu baño. h2Características del Toallero Doble Funky Sensea Blanco de Plástico Abs 55 cm: ul  liFabricado en resistente plástico Abs.  liDiseño doble para mayor capacidad de almacenamiento.  liAcabado brillante y color blanco elegante.  liFácil instalación adosada a la pared.  liIncluye kit de instalación.ul',
#        'Promart te trae tubos y conexiones de la mejor calidad para que puedas establecer las conexiones sanitarias de tu casa, de manera más práctica y fácil.',
#        'Diseñado para durar más tiempo que los sartenes tradicionales. Elegante y fácil de agarrar.',
#        'Producto elaborado a base de resina metacrilada, pigmentos seleccionados resistentes a la luz e intemperie.',
#        'Organiza tus joyas en este bonito joyero de madera con un diseño inspirado en toda la magia de la India. Cuenta con 9 divisiones.¡Descubre la tendencia India!',
#        'Ilumina tus ambientes con este foco incandescente de 60W de potencia, tiempo de duración de 1 año (1000 horas) y adaptado para desprender luz clara.',
#        'Promart trae para ti esta llave para lavatorio de moderno diseño que quedará muy bien dentro de la decoración de tu baño. Fabricada a base de resistente.',
#        'Si lo tuyo es un estilo rústico este piso de cerámica de gran calidad y atractivo diseño es perfecto para renovar tus ambientes.',
#        'Conserva tus ambientes limpios y organizados con este tacho. Un producto elaborado a base de resistente plástico.',
#        'Power Force de la mano de Promart te traen un producto de excelente calidad,  con punta y plantilla de acero elaborado con cuero carnaza afelpada, perfecta para ti que la seguridad del día a día en trabajo pesado es muy importante, lo puedes encontrar disponible en la talla 35.',
#        'Promart trae la silla gamer que maneja un máximo nivel de comodidad y diversión. Ideal para pasar horas en la computadora bien sea jugando o de trabajo. ¡No esperes más y compra ya!',
#        'Disfruta de agua caliente en todo momento con el Hervidor Eléctrico en promart.pe',
#        'Escurridor para platos fabricado en acero que cuenta con espacios para vajilla, cubiertos y tazas o vasos.',
#        'Si deseas cambiar las puertas de interior de tu casa, negocio u oficina, el modelo Verona es una muy buena opción. Fabricado en HDF enchapado con un bonito acabado natural.Disponible en: 65, 70, 75, 80, 85 y 90 cm.',
#        'Conecta tus dispositivos a una mejor forma de recargar energía. Este enchufe puede conectarse a una red wifi.',
#        'Promart te trae este Mini plato de diseño único y excelente calidad.',
#        'Aplique LED para pared de diseño moderno. Proporciona una cálida iluminación indirecta a tus ambientes destacando tu decoración.',
#        'Pelota inflable especialmente diseñada para divertirte en la piscina.Cuenta con 61cm de diámetro.',
#        'Organiza distintos accesorios con esta práctica comoda de plástico que Promart.pe trae para ti.',
#        'Toalla de baño que aporta una gran suavidad. Secado rápido y limpieza sencilla.',
#        'pSimplifica tu vida con el Adaptador de 6 Tomas con Línea Tierra Werken Plano LT en color blanco. Este adaptador te permite conectar hasta 6 enchufes de forma segura y eficiente, con una capacidad máxima de operación de 10A y una tensión nominal de 250V. Con un diseño plano y compacto, este adaptador es ideal para hogares u oficinas. Asegúrate de cumplir con las recomendaciones de uso para garantizar su durabilidad y seguridad. Características del Adaptador de 6 Tomas con Línea Tierra Werken:ul liCapacidad para 6 enchufes. liLínea tierra para mayor seguridad. liDiseño plano y compacto. liMaterial resistente ABS/PC. liGarantía de 1 año./ul',
#        'Mueble Isla de Cocina Cala Melamina Blanco/Ibiza. Disfruta de lo más nuevo que Promart.pe trae para ti.'],
#       dtype=object)

# %%
dfx = pd.DataFrame(columns=["SKU", "CHUNK_DESCRIPCION", "CHUNK_CARACTERISTICAS", "CHUNK_OBSERVACIONES", "CHUNK_RECOMENDACIONES"])

for sku, grupo in dfd.groupby("SKU"):
    carac=''
    obser=''
    descr=''
    recom=''
    for _, row in grupo.iterrows():
        match row['KEY']:
            case 'Características':
                carac=row['VALUE']
            case 'Observaciones':
                obser=row['VALUE']
            case 'Descripción Emocional':
                descr=row['VALUE']
            case 'Recomendaciones De Uso':
                recom=row['VALUE']
    dfx.loc[len(dfx)] = [sku, descr, carac, obser, recom]

dfx
# Out:
#           SKU                                  CHUNK_DESCRIPCION  \
# 0       10001  Atornillador de uso doméstico para realizar di...
# 1       10006  Los rotomartillos son herramientas muy parecid...
# 2       10007  Promart y Total traen para ti esta potente sie...
# 3       10010  Realiza toda clase de trabajos utilizando sola...
# 4       10013  Realiza distintos trabajos con este potente so...
# ...       ...                                                ...
# 71809  165467
# 71810  165468
# 71811  165469
# 71812  165470
# 71813  165471
#
#                                    CHUNK_CARACTERISTICAS CHUNK_OBSERVACIONES  \
# 0      Ligero. Conveniente, cómodo y fácil de usar. D...
# 1
# 2
# 3
# 4
# ...                                                  ...                 ...
# 71809  Doble funcionalidad para distintos tipos de cá...
# 71810  Saltea, sofríe y cocina saludable. Antiadheren...
# 71811  Colorido y fácil de limpiar. Ideal para niños,...
# 71812  Aporta color y estilo a tu mesa. Resistente, a...
# 71813  Versatilidad total en un solo utensilio: ralla...
#
#                                    CHUNK_RECOMENDACIONES
# 0      Usar lentes de seguridad al momento de utiliza...
# 1       Utilizar protectores auditivos y mascarilla p...
# 2       Deberemos utilizar gafas protectoras y nunca,...
# 3
# 4
# ...                                                  ...
# 71809
# 71810
# 71811
# 71812
# 71813
#
# [71814 rows x 5 columns]

# %%
# Productos - Ficha Tecnica - Descripcion y recomendaciones
dfw = pd.merge(df, dfa, on='SKU', how='left')
dfw = pd.merge(dfw, dfx, on='SKU', how='left')
dfw
# Out:
#           SKU                                        DESCRIPCION  \
# 0       10236  OVALIN CIRCULAR P/SOBREP ORANGE VIDRIOTRANSPAR...
# 1       10237    OVALIN CIRCULAR P/SOBREP ORANGE VIDRIO PAVONADO
# 2       10298                  LLAVE DUCHA ORANGE FROST S/SALIDA
# 3       10077                   SILLA ESTAMBUL FIJA H-602F NEGRA
# 4       10177                     MESA DE ESTUDIO ESPAÑA CASTAÑO
# ...       ...                                                ...
# 46708  165495                       MOTOSIERRA (X) 45 CC ESP. 16
# 46709  165491     MOTOSIERRA TOYAMA TCS60FP FARMER PRO - 56CC 20
# 46710  165496                     MINI RODILLO CUBREMAS TEKNO 3"
# 46711  165493                MOTOSIERRA TCS58F-G2-20SN-TY FARMER
# 46712  165497        PODADORA DE ALTURA (XP) 32.6 CC 3/8 X 0.050
#
#              DES_DIV  DES_AREA                DES_DPTO              DES_LIN  \
# 0           ACABADOS     BAÑOS              SANITARIOS             OVALINES
# 1           ACABADOS     BAÑOS              SANITARIOS             OVALINES
# 2           ACABADOS     BAÑOS        GRIFERIA DE BAÑO          LLAVE DUCHA
# 3       HOGAR Y DECO   MUEBLES                OFICINAS         SILLAS FIJAS
# 4       HOGAR Y DECO   MUEBLES                OFICINAS      ESCRITORIOS RTA
# ...              ...       ...                     ...                  ...
# 46708  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46709  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46710       ACABADOS  PINTURAS  ACCESORIOS PARA PINTAR  RODILLOS Y BANDEJAS
# 46711  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN          MOTOSIERRAS
# 46712  JARDIN Y TEMP    JARDIN    MAQUINARIA DE JARDIN            PODADORAS
#
#        DES_MARCA  DES_PROCE  \
# 0         ORANGE  IMPORTADO
# 1         ORANGE  IMPORTADO
# 2         ORANGE  IMPORTADO
# 3         ORANGE  IMPORTADO
# 4      POLITORNO  IMPORTADO
# ...          ...        ...
# 46708         SM   NACIONAL
# 46709         SM   NACIONAL
# 46710      TEKNO  IMPORTADO
# 46711         SM   NACIONAL
# 46712         SM   NACIONAL
#
#                                                      URL  \
# 0      https://promart.vteximg.com.br/arquivos/ids/38...
# 1      https://promart.vteximg.com.br/arquivos/ids/50...
# 2      https://promart.vteximg.com.br/arquivos/ids/51...
# 3      https://promart.vteximg.com.br/arquivos/ids/38...
# 4      https://promart.vteximg.com.br/arquivos/ids/59...
# ...                                                  ...
# 46708
# 46709
# 46710
# 46711
# 46712
#
#                                           CHUNK_PRODUCTO  \
# 0      ovalin circular para sobreponer vidriotranspar...
# 1      ovalin circular para sobreponer vidrio pavonad...
# 2      llave ducha frost sin salida de la marca orang...
# 3      silla estambul fija h-602f negra de la marca o...
# 4      mesa de estudio españa castaño de la marca pol...
# ...                                                  ...
# 46708  motosierra (x) 45 cc esp. 16 de la marca sm de...
# 46709  motosierra toyama tcs60fp farmer pro - 56cc 20...
# 46710  mini rodillo cubremas 3" de la marca tekno del...
# 46711  motosierra tcs58f-g2-20sn-ty farmer de la marc...
# 46712  podadora de altura (xp) 32.6 cc 3/8 x 0.050 de...
#
#                                              CHUNK_FICHA  \
# 0      acabado brillante, tamaño del producto moderad...
# 1      acabado pavonado, tamaño del producto moderado...
# 2      acabado cromado, altura del producto 6.00 cm, ...
# 3      altura del producto 79.00 cm, ancho del produc...
# 4      acabado satinado, altura del producto 76.00 cm...
# ...                                                  ...
# 46708                                                NaN
# 46709                                                NaN
# 46710                                                NaN
# 46711                                                NaN
# 46712                                                NaN
#
#                                        CHUNK_DESCRIPCION  \
# 0      Moderniza la decoración de tu baño con este ov...
# 1      Moderniza la decoración de tu baño con este ov...
# 2      Dale un toque elegante a la grifería de tu duc...
# 3      p¡Dale un toque moderno y funcional a tus espa...
# 4      h2Diseño elegante y funcional con la Mesa de e...
# ...                                                  ...
# 46708                                                NaN
# 46709                                                NaN
# 46710                                                NaN
# 46711                                                NaN
# 46712                                                NaN
#
#                                    CHUNK_CARACTERISTICAS  \
# 0      Ovalín para sobreponer en mesada de baño hecho...
# 1      Ovalín para sobreponer en mesada de baño hecho...
# 2      Llave para ducha convencional de cuerpo interi...
# 3      Silla ideal para oficina, dormitorio o cualqui...
# 4      Estructura de MDP, base del mismo material de ...
# ...                                                  ...
# 46708                                                NaN
# 46709                                                NaN
# 46710                                                NaN
# 46711                                                NaN
# 46712                                                NaN
#
#                                      CHUNK_OBSERVACIONES  \
# 0      Se recomienda complementar la instalación del ...
# 1      Se recomienda complementar la instalación del ...
# 2      Previo a la compra, verificar si se puede adap...
# 3      Silla fija, tiempo de vida estimado 2 años. Vi...
# 4      Mueble Fijo, no es necesario adosarlo a la par...
# ...                                                  ...
# 46708                                                NaN
# 46709                                                NaN
# 46710                                                NaN
# 46711                                                NaN
# 46712                                                NaN
#
#                                    CHUNK_RECOMENDACIONES
# 0      Al momento de instalar no usar cemento ni arci...
# 1      Al momento de instalar no usar cemento ni arci...
# 2      Maniobrar con cuidado para evitar el deterioro...
# 3      Estas sillas pueden ser limpiadas con un limpi...
# 4      Se debe realizar la limpieza de sus muebles co...
# ...                                                  ...
# 46708                                                NaN
# 46709                                                NaN
# 46710                                                NaN
# 46711                                                NaN
# 46712                                                NaN
#
# [46713 rows x 15 columns]

# %%
#len(dfw)
dfw[dfw['CHUNK_FICHA'].isna()]
# Out:
#           SKU                                     DESCRIPCION        DES_DIV  \
# 739     13548          CONECTOR RAPIDO CAÑO - MANGUERA TRUPER  JARDIN Y TEMP
# 1003    27992                  VALE DCTO VISITA TECNICA PISOS          OTROS
# 2472    20166     CUMBRERA PP TEJA ROJA 0.60X0.76M FIBRAFORTE    OBRA GRUESA
# 2473    20167          CUMBRERA PP ROJA 1.10X0.52M FIBRAFORTE    OBRA GRUESA
# 3527    26617                                         REBATES   HOGAR Y DECO
# ...       ...                                             ...            ...
# 46708  165495                    MOTOSIERRA (X) 45 CC ESP. 16  JARDIN Y TEMP
# 46709  165491  MOTOSIERRA TOYAMA TCS60FP FARMER PRO - 56CC 20  JARDIN Y TEMP
# 46710  165496                  MINI RODILLO CUBREMAS TEKNO 3"       ACABADOS
# 46711  165493             MOTOSIERRA TCS58F-G2-20SN-TY FARMER  JARDIN Y TEMP
# 46712  165497     PODADORA DE ALTURA (XP) 32.6 CC 3/8 X 0.050  JARDIN Y TEMP
#
#                          DES_AREA                           DES_DPTO  \
# 739                        JARDIN  MANGUERAS Y ACCESORIOS PARA RIEGO
# 1003                    SERVICIOS                   SERVICIOS TIENDA
# 2472   MATERIALES DE CONSTRUCCION                             TECHOS
# 2473   MATERIALES DE CONSTRUCCION                             TECHOS
# 3527    ORGANIZACION Y DECORACION                            REBATES
# ...                           ...                                ...
# 46708                      JARDIN               MAQUINARIA DE JARDIN
# 46709                      JARDIN               MAQUINARIA DE JARDIN
# 46710                    PINTURAS             ACCESORIOS PARA PINTAR
# 46711                      JARDIN               MAQUINARIA DE JARDIN
# 46712                      JARDIN               MAQUINARIA DE JARDIN
#
#                               DES_LIN   DES_MARCA  DES_PROCE URL  \
# 739               ACCESORIOS DE RIEGO      TRUPER   NACIONAL
# 1003   SERVICIOS INSTALACION - TIENDA   SIN MARCA   NACIONAL
# 2472                 TECHOS PLASTICOS  FIBRAFORTE   NACIONAL
# 2473                  TECHOS DE FIBRA  FIBRAFORTE   NACIONAL
# 3527                          REBATES   SIN MARCA   NACIONAL
# ...                               ...         ...        ...  ..
# 46708                     MOTOSIERRAS          SM   NACIONAL
# 46709                     MOTOSIERRAS          SM   NACIONAL
# 46710             RODILLOS Y BANDEJAS       TEKNO  IMPORTADO
# 46711                     MOTOSIERRAS          SM   NACIONAL
# 46712                       PODADORAS          SM   NACIONAL
#
#                                           CHUNK_PRODUCTO CHUNK_FICHA  \
# 739    conector rapido caño - manguera de la marca tr...         NaN
# 1003   vale dcto visita tecnica pisos de la marca sin...         NaN
# 2472   cumbrera pp teja roja 0.60x0.76m de la marca f...         NaN
# 2473   cumbrera pp roja 1.10x0.52m de la marca fibraf...         NaN
# 3527   rebates de la marca sin marca del area de orga...         NaN
# ...                                                  ...         ...
# 46708  motosierra (x) 45 cc esp. 16 de la marca sm de...         NaN
# 46709  motosierra toyama tcs60fp farmer pro - 56cc 20...         NaN
# 46710  mini rodillo cubremas 3" de la marca tekno del...         NaN
# 46711  motosierra tcs58f-g2-20sn-ty farmer de la marc...         NaN
# 46712  podadora de altura (xp) 32.6 cc 3/8 x 0.050 de...         NaN
#
#       CHUNK_DESCRIPCION CHUNK_CARACTERISTICAS CHUNK_OBSERVACIONES  \
# 739                 NaN                   NaN                 NaN
# 1003                NaN                   NaN                 NaN
# 2472                NaN                   NaN                 NaN
# 2473                NaN                   NaN                 NaN
# 3527                NaN                   NaN                 NaN
# ...                 ...                   ...                 ...
# 46708               NaN                   NaN                 NaN
# 46709               NaN                   NaN                 NaN
# 46710               NaN                   NaN                 NaN
# 46711               NaN                   NaN                 NaN
# 46712               NaN                   NaN                 NaN
#
#       CHUNK_RECOMENDACIONES
# 739                     NaN
# 1003                    NaN
# 2472                    NaN
# 2473                    NaN
# 3527                    NaN
# ...                     ...
# 46708                   NaN
# 46709                   NaN
# 46710                   NaN
# 46711                   NaN
# 46712                   NaN
#
# [223 rows x 15 columns]

# %%
dfww = dfw.dropna(subset='CHUNK_FICHA')
dfww
# Out:
#           SKU                                        DESCRIPCION  \
# 0       10236  OVALIN CIRCULAR P/SOBREP ORANGE VIDRIOTRANSPAR...
# 1       10237    OVALIN CIRCULAR P/SOBREP ORANGE VIDRIO PAVONADO
# 2       10298                  LLAVE DUCHA ORANGE FROST S/SALIDA
# 3       10077                   SILLA ESTAMBUL FIJA H-602F NEGRA
# 4       10177                     MESA DE ESTUDIO ESPAÑA CASTAÑO
# ...       ...                                                ...
# 46683  165369                            BOXET DELUXE QUEEN GRIS
# 46684  165387             CAMA BOXET POCKET STAR QUEEN CHOCOLATE
# 46685  165375        DORMITORIO BOXET POCKET MAX QUEEN CHOCOLATE
# 46686  165376        CAMA BOXET POCKET STAR 1.5 PLAZAS CHOCOLATE
# 46687  165378  DORMITORIO BOXET POCKET STAR 1.5 PLAZAS CHAMPAGNE
#
#             DES_DIV DES_AREA          DES_DPTO          DES_LIN  DES_MARCA  \
# 0          ACABADOS    BAÑOS        SANITARIOS         OVALINES     ORANGE
# 1          ACABADOS    BAÑOS        SANITARIOS         OVALINES     ORANGE
# 2          ACABADOS    BAÑOS  GRIFERIA DE BAÑO      LLAVE DUCHA     ORANGE
# 3      HOGAR Y DECO  MUEBLES          OFICINAS     SILLAS FIJAS     ORANGE
# 4      HOGAR Y DECO  MUEBLES          OFICINAS  ESCRITORIOS RTA  POLITORNO
# ...             ...      ...               ...              ...        ...
# 46683  HOGAR Y DECO  MUEBLES       DORMITORIOS        COLCHONES    PARAISO
# 46684  HOGAR Y DECO  MUEBLES       DORMITORIOS        COLCHONES    PARAISO
# 46685  HOGAR Y DECO  MUEBLES       DORMITORIOS        COLCHONES    PARAISO
# 46686  HOGAR Y DECO  MUEBLES       DORMITORIOS        COLCHONES    PARAISO
# 46687  HOGAR Y DECO  MUEBLES       DORMITORIOS        COLCHONES    PARAISO
#
#        DES_PROCE                                                URL  \
# 0      IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/38...
# 1      IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/50...
# 2      IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/51...
# 3      IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/38...
# 4      IMPORTADO  https://promart.vteximg.com.br/arquivos/ids/59...
# ...          ...                                                ...
# 46683   NACIONAL
# 46684   NACIONAL
# 46685   NACIONAL
# 46686   NACIONAL
# 46687   NACIONAL
#
#                                           CHUNK_PRODUCTO  \
# 0      ovalin circular para sobreponer vidriotranspar...
# 1      ovalin circular para sobreponer vidrio pavonad...
# 2      llave ducha frost sin salida de la marca orang...
# 3      silla estambul fija h-602f negra de la marca o...
# 4      mesa de estudio españa castaño de la marca pol...
# ...                                                  ...
# 46683  boxet deluxe queen gris de la marca paraiso de...
# 46684  cama boxet pocket star queen chocolate de la m...
# 46685  dormitorio boxet pocket max queen chocolate de...
# 46686  cama boxet pocket star 1.5 plazas chocolate de...
# 46687  dormitorio boxet pocket star 1.5 plazas champa...
#
#                                              CHUNK_FICHA  \
# 0      acabado brillante, tamaño del producto moderad...
# 1      acabado pavonado, tamaño del producto moderado...
# 2      acabado cromado, altura del producto 6.00 cm, ...
# 3      altura del producto 79.00 cm, ancho del produc...
# 4      acabado satinado, altura del producto 76.00 cm...
# ...                                                  ...
# 46683  altura del producto 35 cm, ancho del producto ...
# 46684  altura del producto 65 cm, ancho del producto ...
# 46685  altura del producto 134 cm, ancho del producto...
# 46686  altura del producto 65 cm, ancho del producto ...
# 46687  altura del producto 135 cm, ancho del producto...
#
#                                        CHUNK_DESCRIPCION  \
# 0      Moderniza la decoración de tu baño con este ov...
# 1      Moderniza la decoración de tu baño con este ov...
# 2      Dale un toque elegante a la grifería de tu duc...
# 3      p¡Dale un toque moderno y funcional a tus espa...
# 4      h2Diseño elegante y funcional con la Mesa de e...
# ...                                                  ...
# 46683  Boxet Paraíso Deluxe Queen Gris. Disfruta de l...
# 46684  Cama Boxet Paraíso Pocket Star Queen Chocolate...
# 46685  Dormitorio Boxet Paraíso Pocket Max Queen Choc...
# 46686  Cama Boxet Paraíso Pocket Star 1.5 Plazas Choc...
# 46687  Dormitorio Boxet Paraíso Pocket Star 1.5 Plaza...
#
#                                    CHUNK_CARACTERISTICAS  \
# 0      Ovalín para sobreponer en mesada de baño hecho...
# 1      Ovalín para sobreponer en mesada de baño hecho...
# 2      Llave para ducha convencional de cuerpo interi...
# 3      Silla ideal para oficina, dormitorio o cualqui...
# 4      Estructura de MDP, base del mismo material de ...
# ...                                                  ...
# 46683  Descubre el nuevo Boxet Deluxe y organiza tu e...
# 46684  Gracias a su diseño con ergosoft maximiza la s...
# 46685  Pocket Max ha sido elaborado con resortes pock...
# 46686  Gracias a su diseño con ergosoft maximiza la s...
# 46687  Gracias a su diseño con ergosoft maximiza la s...
#
#                                      CHUNK_OBSERVACIONES  \
# 0      Se recomienda complementar la instalación del ...
# 1      Se recomienda complementar la instalación del ...
# 2      Previo a la compra, verificar si se puede adap...
# 3      Silla fija, tiempo de vida estimado 2 años. Vi...
# 4      Mueble Fijo, no es necesario adosarlo a la par...
# ...                                                  ...
# 46683                            Imágenes referenciales.
# 46684                            Imágenes referenciales.
# 46685                            Imágenes referenciales.
# 46686                            Imágenes referenciales.
# 46687                            Imágenes referenciales.
#
#                                    CHUNK_RECOMENDACIONES
# 0      Al momento de instalar no usar cemento ni arci...
# 1      Al momento de instalar no usar cemento ni arci...
# 2      Maniobrar con cuidado para evitar el deterioro...
# 3      Estas sillas pueden ser limpiadas con un limpi...
# 4      Se debe realizar la limpieza de sus muebles co...
# ...                                                  ...
# 46683                       Revisar Cartilla de Usuario.
# 46684                       Revisar Cartilla de Usuario.
# 46685                       Revisar Cartilla de Usuario.
# 46686                       Revisar Cartilla de Usuario.
# 46687                       Revisar Cartilla de Usuario.
#
# [46490 rows x 15 columns]

# %%
dfww.to_csv('../data/processed/productos_corpus.csv', index=False)

# %%
def getChunkSku(sku):
    result = dfww[dfww['SKU'] == sku][['DESCRIPCION', 'CHUNK_PRODUCTO', 'CHUNK_FICHA', 'CHUNK_DESCRIPCION', 'CHUNK_CARACTERISTICAS', 'CHUNK_OBSERVACIONES', 'CHUNK_RECOMENDACIONES']].values.tolist()
    return result[0]

# %%
getChunkSku(165375)
# Out:
# ['DORMITORIO BOXET POCKET MAX QUEEN CHOCOLATE',
#  'dormitorio boxet pocket max queen chocolate de la marca paraiso del area de muebles para los dormitorios de la linea colchones de procedencia nacional',
#  'altura del producto 134 cm, ancho del producto 152 cm, profundidad del producto 203 cm, volumen del producto 4134704, ean 2000001653753, medidas 152x203x134, tipo de producto colchón + tarima, modelo pocket max, color marrón, material espuma, garantía 8 años, procedencia nacional, país de origen perú',
#  'Dormitorio Boxet Paraíso Pocket Max Queen Chocolate. Disfruta de lo más nuevo que Promart.pe trae para ti.',
#  'Pocket Max ha sido elaborado con resortes pocket encapsulados para que nada interrumpa tu sueño y capas de espuma Zebra 23 que brindarán una mayor estabilidad a tu colchón. Además, su tela tejida de punto aportará frescura a tu descanso.',
#  'Imágenes referenciales.',
#  'Revisar Cartilla de Usuario.']

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import pandas as pd

# Lista de stopwords en español
stopwords_es = stopwords.words('spanish')

def imprimirGraficoTfIdf(lista):
    # Tu lista de textos (puedes reemplazarla si ya la tienes cargada)
    textos = lista[1:]

    # Vectorizar con TF-IDF y stopwords en español
    vectorizer = TfidfVectorizer(stop_words=stopwords_es)
    tfidf_matrix = vectorizer.fit_transform(textos)

    # Sumar los pesos TF-IDF por palabra en todo el corpus
    suma_tfidf = tfidf_matrix.sum(axis=0).A1
    palabras = vectorizer.get_feature_names_out()

    # Crear DataFrame con resultados
    dfx = pd.DataFrame({'palabra': palabras, 'tfidf': suma_tfidf})
    dfx = dfx.sort_values(by='tfidf', ascending=False).head(20)

    # Graficar
    plt.figure(figsize=(10, 6))
    plt.barh(dfx['palabra'], dfx['tfidf'], color='skyblue')
    plt.xlabel('Peso TF-IDF total')
    plt.title(f'{lista[0]} \n Top 20 palabras más importantes (TF-IDF)')
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/andlody/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
imprimirGraficoTfIdf(getChunkSku(165375))

# %%
imprimirGraficoTfIdf(getChunkSku(10237))

# %%
import pandas as pd

df = pd.read_csv("procesos/productos_corpus.csv",delimiter=",")

# %%
dfx = pd.DataFrame()
dfx['CHUNK_PRODUCTO'] = df.sample(n=500)['CHUNK_PRODUCTO']
dfx['PREGUNTA'] = ''
dfx['ES_ABIERTA'] = ''
dfx['RESPUESTA'] = ''

dfx
# Out:
#                                           CHUNK_PRODUCTO PREGUNTA ES_ABIERTA  \
# 40485  piso barcelona 60x60 rustico 1.44 de la marca ...
# 2319   lampara colgante valencia plateada 1 luz ***w ...
# 3542   placa simple nylon para interruptor marfil de ...
# 46281  fibra metálica para concreto por bolsa de 20kg...
# 23300  caja herramientas master box #14 de la marca p...
# ...                                                  ...      ...        ...
# 14508  fibrodisco expert for metal, 115x22.23mm, g80 ...
# 25179  aplique slots e27 gris de la marca inspire del...
# 39142  piso oxford grafito 60x60 m2 de la marca san l...
# 11128  coc petra 5 hornilla neg hor eléctrico gamma p...
# 16787  dado seire larga dh  14 mm 1/4" de la marca ba...
#
#       RESPUESTA
# 40485
# 2319
# 3542
# 46281
# 23300
# ...         ...
# 14508
# 25179
# 39142
# 11128
# 16787
#
# [500 rows x 4 columns]

# %%
df = pd.read_csv("procesos/productos_preguntas_completado.csv",delimiter=",")
df.head()
# Out:
#                                       CHUNK_PRODUCTO  \
# 0  sikaflex 221 blanco x 600 ml de la marca sika ...
# 1  maceta cuadr piedra 30x30x30cm con sist. riego...
# 2  cuchilla plastica econo de la marca home tools...
# 3  coladera redonda abs con rejilla cromada abs d...
# 4  guirnalda de pompones blancos 1.8m c.natural d...
#
#                                             PREGUNTA  ES_ABIERTA  \
# 0  ¿Qué beneficios ofrece el producto sikaflex 22...           1
# 1  ¿Por qué elegir el producto maceta cuadr piedr...           1
# 2  ¿Se puede usar el producto cuchilla plastica e...           0
# 3  ¿Qué características destacan del producto col...           1
# 4  ¿Se puede usar el producto guirnalda de pompon...           0
#
#                                            RESPUESTA
# 0  El producto sikaflex 221 blanco x 600 ml de la...
# 1  El producto maceta cuadr piedra 30x30x30cm con...
# 2                    Sí, en la mayoría de los casos.
# 3  El producto coladera redonda abs con rejilla c...
# 4                                Depende del modelo.

# %%
import pandas as pd
import random

# Para cada fila, elegir una columna al azar y extraer (columna, valor)
resultados = []
chunks = ['CHUNK_PRODUCTO', 'CHUNK_FICHA', 'CHUNK_DESCRIPCION', 'CHUNK_CARACTERISTICAS', 'CHUNK_OBSERVACIONES', 'CHUNK_RECOMENDACIONES']
for _, row in df.iterrows():
    col = random.choice(chunks)
    val = row[col]
    resultados.append({'CHUNK': val, 'TIPO': col.replace('CHUNK_',''), 'PREGUNTA':'', 'RESPUESTA':''})

# Convertir a DataFrame
df_chunks = pd.DataFrame(resultados)
df_chunks
# Out:
#                                                    CHUNK             TIPO  \
# 0      Se recomienda complementar la instalación del ...    OBSERVACIONES
# 1      Moderniza la decoración de tu baño con este ov...      DESCRIPCION
# 2      Dale un toque elegante a la grifería de tu duc...      DESCRIPCION
# 3      silla estambul fija h-602f negra de la marca o...         PRODUCTO
# 4      h2Diseño elegante y funcional con la Mesa de e...      DESCRIPCION
# ...                                                  ...              ...
# 46485  Descubre el nuevo Boxet Deluxe y organiza tu e...  CARACTERISTICAS
# 46486  altura del producto 65 cm, ancho del producto ...            FICHA
# 46487                            Imágenes referenciales.    OBSERVACIONES
# 46488                            Imágenes referenciales.    OBSERVACIONES
# 46489                       Revisar Cartilla de Usuario.  RECOMENDACIONES
#
#       PREGUNTA RESPUESTA
# 0
# 1
# 2
# 3
# 4
# ...        ...       ...
# 46485
# 46486
# 46487
# 46488
# 46489
#
# [46490 rows x 4 columns]

# %%
df_chunks = df_chunks.dropna(subset='CHUNK')
df_chunks = df_chunks.sample(n=1000)
df_chunks.to_csv('procesos/preguntas_chunk.csv', index=False)

# %%
df = pd.read_csv("procesos/preguntas_chunk_completado.csv",delimiter=",")
df.sample(n=100).head(100)
# Out:
#                                                  CHUNK             TIPO  \
# 833  Compuesto de dos gruesos bloques de cristal qu...  CARACTERISTICAS
# 237  altura del producto 11.50 cm, ancho del produc...            FICHA
# 565  Se recomienda utilizar elementos de seguridad,...  RECOMENDACIONES
# 732  Tipo resorte para puerta, fabricado en acero, ...  CARACTERISTICAS
# 399  manilla 128mm niquel cepillado de la marca gam...         PRODUCTO
# ..                                                 ...              ...
# 451  Compare visualmente las piezas para verificar ...  RECOMENDACIONES
# 678  Rectas. De sección circular, con resaltes Hi-b...  CARACTERISTICAS
# 420  altura del producto 12.50 cm, ancho del produc...            FICHA
# 304  altura del producto 3.90 cm, ancho del product...            FICHA
# 312  Pocket Max ha sido elaborado con resortes pock...  CARACTERISTICAS
#
#                                               PREGUNTA  \
# 833                   ¿Qué se indica sobre el modelo ?
# 237                   ¿Qué se indica sobre el modelo ?
# 565     ¿Qué recomendaciones se deben seguir al usar ?
# 732                   ¿Qué se indica sobre el modelo ?
# 399  ¿Qué características tiene el modelo manilla 1...
# ..                                                 ...
# 451     ¿Qué recomendaciones se deben seguir al usar ?
# 678                   ¿Qué se indica sobre el modelo ?
# 420                   ¿Qué se indica sobre el modelo ?
# 304                   ¿Qué se indica sobre el modelo ?
# 312                   ¿Qué se indica sobre el modelo ?
#
#                                              RESPUESTA
# 833  Compuesto de dos gruesos bloques de cristal qu...
# 237  altura del producto 11.50 cm, ancho del produc...
# 565  Se recomienda utilizar elementos de seguridad,...
# 732  Tipo resorte para puerta, fabricado en acero, ...
# 399  manilla 128mm niquel cepillado de la marca gam...
# ..                                                 ...
# 451  Compare visualmente las piezas para verificar ...
# 678  Rectas. De sección circular, con resaltes Hi-b...
# 420  altura del producto 12.50 cm, ancho del produc...
# 304  altura del producto 3.90 cm, ancho del product...
# 312  Pocket Max ha sido elaborado con resortes pock...
#
# [100 rows x 4 columns]
